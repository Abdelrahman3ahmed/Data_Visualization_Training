# %%
from dash import Dash , html, dcc
import jupyter_dash

# %%
app = Dash()

# %%
import plotly.express as px
import pandas as pd

# %%
UR_Data = pd.read_csv("Russia-Ukraine Equipment Losses - Origional.csv")
UR_Data.head()
# Out:
#          Date  Russia_Total  Ukraine_Total  Unnamed: 3  Russia_Destroyed  \
# 0  2022-02-24             0              0         NaN                 0
# 1  2022-02-25            52             59         NaN                25
# 2  2022-02-26           107             88         NaN                42
# 3  2022-02-27           161             96         NaN                71
# 4  2022-02-28           321            147         NaN               139
#
#    Ukraine_Destroyed  Unnamed: 6  Russia_Damaged  Ukraine_Damaged  Unnamed: 9  \
# 0                  0         NaN               0                0         NaN
# 1                 27         NaN               5                5         NaN
# 2                 36         NaN               6                4         NaN
# 3                 38         NaN               6                4         NaN
# 4                 53         NaN               7                4         NaN
#
#    ...  Russia_Logistics  Ukraine_Logistics  Unnamed: 52  Russia_Armor  \
# 0  ...                 3                  0          NaN             6
# 1  ...                 3                  0          NaN             9
# 2  ...                14                  0          NaN            14
# 3  ...                14                  0          NaN            20
# 4  ...                18                  0          NaN            72
#
#    Ukraine_Armor  Unnamed: 55  Russia_Antiair  Ukraine_Antiair  Unnamed: 58  \
# 0              3          NaN               1                5          NaN
# 1              5          NaN               2                5          NaN
# 2             14          NaN               3                5          NaN
# 3             17          NaN               4                5          NaN
# 4             27          NaN              15                5          NaN
#
#    UNHCR Ukraine Refugees
# 0                 84681.0
# 1                192982.0
# 2                341301.0
# 3                509665.0
# 4                672139.0
#
# [5 rows x 60 columns]

# %%
UR_Data = UR_Data.dropna(axis = 1)

# %%
app.layout = html.Div(children=[
    
    dcc.Graph(id = "UR_Graph"),
    dcc.Dropdown(UR_Data.columns, 'Date', id='Select_Y_axis' ),
#     html.Button(id='Plot_Graph', children = 'Show Graph' , n_clicks=0),
    
    
    
    
    
])

# %%
from dash.dependencies import Input , Output , State

# %%
@app.callback(
    Output('UR_Graph', 'figure'),
    Input('Select_Y_axis', 'value'),
#     Input('Plot_Graph' , 'n_clicks')
)
def update_output(Yaxis_value):
#     Updated_graph = UR_Data[["Date" , "Russia_Total"]]
    draw = px.line(UR_Data , x='Date' , y =Yaxis_value )

    return draw

# %%
app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_3_0m1648035509.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_3_0m1648035509.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_3_0m1648035509.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/deps/react@16.v2_3_0m1648035509.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_3_0m1648035509.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/dash_table/bundle.v5_1_1m1648035509.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_2m1648035509.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_3_0m1648035509.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_3_0m1648035509.js HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [09/Apr/2022 02:26:22] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [09/Apr/2022 02:26:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:27] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Apr/2022 02:26:29] "POST /_dash-update-component HTTP/1.1" 200 -
